# %% [markdown]
# # BELAJAR MENGELOLA DATA DENGAN PHYTON

# %% [markdown]
# # 1.  Mengimport data tabel .csv

# %%
import pandas as pd

# %%
df = pd.read_csv("Anaconda3/Assessment R & Python_ Dataset_superstore_simple.csv")

# %%
df
# Out:
#             order_id  order_date customer_id      segment         category  \
# 0     CA-2016-152156  2016-11-08    CG-12520     Consumer        Furniture
# 1     CA-2016-152156  2016-11-08    CG-12520     Consumer        Furniture
# 2     CA-2016-138688  2016-06-12    DV-13045    Corporate  Office Supplies
# 3     US-2015-108966  2015-10-11    SO-20335     Consumer        Furniture
# 4     US-2015-108966  2015-10-11    SO-20335     Consumer  Office Supplies
# 5     CA-2014-115812  2014-06-09    BH-11710     Consumer        Furniture
# 6     CA-2014-115812  2014-06-09    BH-11710     Consumer  Office Supplies
# 7     CA-2014-115812  2014-06-09    BH-11710     Consumer       Technology
# 8     CA-2014-115812  2014-06-09    BH-11710     Consumer  Office Supplies
# 9     CA-2014-115812  2014-06-09    BH-11710     Consumer  Office Supplies
# 10    CA-2014-115812  2014-06-09    BH-11710     Consumer        Furniture
# ...

# %% [markdown]
# # 2. Mencari Nilai tertinggi dari kolom sales

# %%
maxsales = max(df.sales)

# %%
maxsales
# Out:
# 9892.74

# %% [markdown]
# # Menampilkan letak nilai tertinggi penjualan terletak di nomor 9033

# %%
filtertabel = df[(df.sales == 9892.74 )]

# %%
filtertabel
# Out:
#             order_id  order_date customer_id   segment         category  \
# 9033  CA-2016-117121  2016-12-17    AB-10105  Consumer  Office Supplies
#
#      sub_category    sales  quantity   profit
# 9033      Binders  9892.74        13  4946.37

# %% [markdown]
# # 3. Memfilter tabel untuk menampilkan yang berkategori office supplies saja

# %%
filtertabel2 = df[(df.category == "Office Supplies" )]

# %%
filtertabel2
# Out:
#             order_id  order_date customer_id      segment         category  \
# 2     CA-2016-138688  2016-06-12    DV-13045    Corporate  Office Supplies
# 4     US-2015-108966  2015-10-11    SO-20335     Consumer  Office Supplies
# 6     CA-2014-115812  2014-06-09    BH-11710     Consumer  Office Supplies
# 8     CA-2014-115812  2014-06-09    BH-11710     Consumer  Office Supplies
# 9     CA-2014-115812  2014-06-09    BH-11710     Consumer  Office Supplies
# 12    CA-2017-114412  2017-04-15    AA-10480     Consumer  Office Supplies
# 13    CA-2016-161389  2016-12-05    IM-15070     Consumer  Office Supplies
# 14    US-2015-118983  2015-11-22    HP-14815  Home Office  Office Supplies
# 15    US-2015-118983  2015-11-22    HP-14815  Home Office  Office Supplies
# 16    CA-2014-105893  2014-11-11    PK-19075     Consumer  Office Supplies
# 17    CA-2014-167164  2014-05-13    AG-10270     Consumer  Office Supplies
# ...

# %% [markdown]
# # tabel dengan kategori office supplies, dikelompokkan berdasarkan sub kategorinya, untuk kemudian dihitung jumlahnya

# %%
grup = filtertabel2.groupby('sub_category').count()

# %%
grup
# Out:
#               order_id  order_date  customer_id  segment  category  sales  \
# sub_category
# Appliances         466         466          466      466       466    466
# Art                796         796          796      796       796    796
# Binders           1523        1523         1523     1523      1523   1523
# Envelopes          254         254          254      254       254    254
# Fasteners          217         217          217      217       217    217
# Labels             364         364          364      364       364    364
# Paper             1370        1370         1370     1370      1370   1370
# Storage            846         846          846      846       846    846
# Supplies           190         190          190      190       190    190
#
#               quantity  profit
# sub_category
# Appliances         466     466
# Art                796     796
# Binders           1523    1523
# Envelopes          254     254
# Fasteners          217     217
# ...

# %% [markdown]
# # 4. Menampilkan nilai profit negatif / kerugian

# %%
for number in df.profit:
    if number < 0:
        print (number)
# Out:
# -383.031
# -123.85799999999999
# -3.8160000000000003
# -1.0196
# -1665.0522
# -7.0532
# -5.715
# -147.963
# -46.9764
# -15.147
# -15.2225
# -114.3912
# -18.195999999999998
# -1.9344
# -5.8248
# -14.475
# -48.9549
# -3.7880000000000003
# -10.7973
# -3.0396
# -26.8758
# -3.8385
# -25.8174
# -115.7156
# -8.5794
# -407.68199999999996
# -1.8308
# -9.1602
# -11.994000000000002
# -1359.9920000000002
# -58.6347
# -24.858
# -453.849
# -131.12
# -243.16
# -11.3372
# -3.7715
# -2.2586
# -161.875
# -178.9668
# -244.32299999999998
# -14.6958
# -950.4
# -13.8432
# -383.9904
# -28.2744
# -12.432
# -102.04799999999999
# -248.2458
# -3.552
# -7.7247
# -356.728
# -4.6752
# -120.51299999999999
# -2.8308
# -8.4924
# -19.5624
# -4.466
# -509.99699999999996
# -251.9958
# -7.4416
# -3.432
# -169.372
# -204.3145
# -48.7032
# -24.5646
# -62.88
# -131.445
# -67.8762
# -258.5016
# -27.6936
# -20.7
# -13.815999999999999
# -3.4272
# -17.4588
# -407.976
# -2.22
# -4.8588
# -5.712000000000001
# -29.94
# -297.6848
# ...

# %% [markdown]
# # 5. Menghitung jumlah data berdasarkan customer id nya

# %%
filtertabel3 = df[(df.customer_id == "KH-16510")].count()
filtertabel4 = df[(df.customer_id == "AD-10180")].count()
filtertabel5 = df[(df.customer_id == "JE-16165")].count()

# %%
print(filtertabel3)
print(filtertabel4)
print(filtertabel5)
# Out:
# order_id        23
# order_date      23
# customer_id     23
# segment         23
# category        23
# sub_category    23
# sales           23
# quantity        23
# profit          23
# dtype: int64
# order_id        12
# order_date      12
# customer_id     12
# segment         12
# category        12
# sub_category    12
# sales           12
# quantity        12
# profit          12
# dtype: int64
# order_id        7
# order_date      7
# customer_id     7
# segment         7
# category        7
# sub_category    7
# sales           7
# quantity        7
# profit          7
# dtype: int64

# %% [markdown]
# # 6. Menampilkan 5 data terakhir

# %%
df.tail(5)
# Out:
#             order_id  order_date customer_id   segment         category  \
# 9983  CA-2014-110422  2014-01-21    TB-21400  Consumer        Furniture
# 9984  CA-2017-121258  2017-02-26    DB-13060  Consumer        Furniture
# 9985  CA-2017-121258  2017-02-26    DB-13060  Consumer       Technology
# 9986  CA-2017-121258  2017-02-26    DB-13060  Consumer  Office Supplies
# 9987  CA-2017-119914  2017-05-04    CC-12220  Consumer  Office Supplies
#
#      sub_category    sales  quantity   profit
# 9983  Furnishings   25.248         3   4.1028
# 9984  Furnishings   91.960         2  15.6332
# 9985       Phones  258.576         2  19.3932
# 9986        Paper   29.600         4  13.3200
# 9987   Appliances  243.160         2  72.9480

# %% [markdown]
# # 7. Contoh membuat Grafik dengan Phyton

# %%
import matplotlib.pyplot as plt

# %%
x=df.tail(5)
filtertabel3 = x.customer_id

# %%
filtertabel3
# Out:
# 9983    TB-21400
# 9984    DB-13060
# 9985    DB-13060
# 9986    DB-13060
# 9987    CC-12220
# Name: customer_id, dtype: object

# %%
filtertabel4 = x.sales
filtertabel4
# Out:
# 9983     25.248
# 9984     91.960
# 9985    258.576
# 9986     29.600
# 9987    243.160
# Name: sales, dtype: float64

# %%
plt.scatter(filtertabel3,filtertabel4)
plt.show()
